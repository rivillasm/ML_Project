# %% [markdown]
# # UI - UserInterface
#
# *app.py

# %% [markdown]
# ![image.png](attachment:3c25d4e1-667b-4372-9b8c-412359181223.png)

# %% [markdown]
# ![image.png](attachment:0a37c228-d6fb-4ea7-b524-86df2958ab21.png)

# %% [markdown]
# * go to the webbrowser
#
# ![image.png](attachment:9ccb9df1-bc09-492e-9f3d-b4b3192f961e.png)
