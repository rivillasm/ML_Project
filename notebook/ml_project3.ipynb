# %% [markdown]
# * Based on the config|schema.yaml we need to create constants
#
# ![image.png](attachment:cd96e0e8-7d10-4579-a9ab-e8a7518bd977.png)

# %% [markdown]
# * add the constants housing|constant|__init__py"
#
# ![image.png](attachment:8a273cc2-697c-44cb-9b3d-e126ccfd7581.png)

# %% [markdown]
# * fill script for trasnformation  "|housing|config|configuration.py"
#
# ![image.png](attachment:b219ab4f-9e22-4c50-b1cc-6844b0a51508.png)
#
# ![image.png](attachment:526d7a84-7846-498e-8a82-6392e22c4e8b.png)

# %% [markdown]
# * next , create the component file housing|component|data_trasnformation.py

# %% [markdown]
# * populate housing|entity|data_trasnformation.py" file
#
# ![image.png](attachment:901e15bf-3155-41a6-a7f0-2fda96c9e90f.png)

# %% [markdown]
# * in the schema.yaml file add numerical y categorical features
#
# ![image.png](attachment:c1296c55-e629-410d-ab7d-e828f5e20d26.png)
#
# * add the constant values into the "constant|__init__.py" file also
#
# ![image.png](attachment:39a020e6-a635-4b07-aaf6-cb8ac8a7e1f3.png)

# %% [markdown]
# * update the "housing|util|util.py" file
#
# ![image.png](attachment:a21a3d2d-b3cf-4944-9127-5bb7b282f5e8.png)
#
# ![image.png](attachment:be094d78-2e4e-4691-9555-d84826410540.png)

# %% [markdown]
# * update the "housing|pipeline|pipeline.py" file
