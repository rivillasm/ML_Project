# %% [markdown]
# # PREPARING THE COFIG DIRECTORY

# %% [markdown]
# * in the terminal, install the ipykernel, to access the jupyter notebook inside the pycharm terminal
# #### pip install ipykernel

# %%
###  import library
# !pip install ipykernel    # allows running the notebook within the pycharm terminal, make sure the env is activated

# %%
from collections import namedtuple

# %% [markdown]
# #### info necessary to collect the data
# 1. Download url
# 2. Download folder (compressed file)
# 3. extract folder (extraced file)
# 4. train dataset folder
# 5. test dataset folder

# %%
# info necessary to collect the data
DataIngestionConfig = namedtuple("DataIngestionConfig", 
                    ["dataset_download_url","tgz_download_dir","raw_data_dir","ingested_train_dir","ingested_test_dir"])

# %%
data_ingestion_config = DataIngestionConfig(dataset_download_url="text1",
                    tgz_download_dir="text2",
                    raw_data_dir="text3",
                    ingested_train_dir="text4",
                    ingested_test_dir="text5")
                    
data_ingestion_config
# Out:
# DataIngestionConfig(dataset_download_url='text1', tgz_download_dir='text2', raw_data_dir='text3', ingested_train_dir='text4', ingested_test_dir='text5')

# %% [markdown]
# * preparation of the config_entity file:
#
# ![image.png](attachment:053485fd-e7bc-4533-bd09-ba07b09b3384.png)

# %% [markdown]
# * Create a directory called "config" in the main directory (note, it is diff to the config folder inside the housing folder)
# * craete a file named "config.yaml" - this file when run creates a dictionary with all the variables
# * populate the file with all the values for the variables in the config_entity file created above
#
# ![image.png](attachment:80fad77d-9d42-4c81-be4f-588b8fcd4724.png)

# %% [markdown]
# * Go to the "configuration" file, the one locaated inside of the  "housing" folder
# * create the "configuration.py" file and populate it
#
# ![image.png](attachment:4df23eb3-ef9d-4d3c-8cf8-9dceb0dd8bea.png)

# %% [markdown]
# * not lets add the PyYAML library
# * run in the terminal "pip install PyYAML", make sure the environment is active
#
# ![image.png](attachment:c420b570-5faa-4db6-ac89-ee7a7513d281.png)

# %%
# lets check the directory
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rivil\\PycharmProjects\\projects\\ML_Project\\notebook'

# %%
# setting a new world directory
os.chdir('C:\\Users\\rivil\\PycharmProjects\\projects\\ML_Project')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rivil\\PycharmProjects\\projects\\ML_Project'

# %%
os.listdir(".")
# Out:
# ['.dockerignore',
#  '.git',
#  '.github',
#  '.gitignore',
#  '.idea',
#  '.ipynb_checkpoints',
#  'app.py',
#  'config',
#  'Dockerfile',
#  'housing',
#  'housing_logs',
#  'housing_predictor.egg-info',
#  'notebook',
#  'README.md',
#  'requirements.txt',
#  'setup.py',
#  'venv']

# %%
config_file_path = os.path.join("config","config.yaml")  # creates a path based on your specific system 
config_file_path
# Out:
# 'config\\config.yaml'

# %%
os.path.exists(config_file_path)  # checks if the file exists
# Out:
# True

# %%
# read a yaml file
import yaml

config_info=None
with open(config_file_path,"rb") as yaml_file:
    config_info=yaml.safe_load(yaml_file)
    
config_info
# Out:
# {'training_pipeline_config': {'pipeline_name': 'housing',
#   'artifact_dir': 'artifact'},
#  'data_ingestion_config': {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#   'raw_data_dir': 'raw_data',
#   'tgz_download_dir': 'tgz_data',
#   'ingested_dir': 'ingested_data',
#   'ingested_train_dir': 'train',
#   'ingested_test_dir': 'test'},
#  'data_validation_config': {'schema_file_name': 'schema.yaml'},
#  'data_trasnformation_config': {'add_bedroom_per_room': True,
#   'transformed_dir': 'trasnformed_data',
#   'trasnformed_train_dir': 'train',
#   'transformed_test_dir': 'test',
#   'preprocessing_dir': 'preprocessed',
#   'preprocessed_object_file_name': 'preprocessed.pkl'},
#  'model_trainer_config': {'trained_model_dir': 'trained_model',
#   'model_file_name': 'model.pkl',
#   'base_acuracy': 0.6},
#  'model_evaluation_config': {'model_evaluation_file_name': 'model_evaluation.yaml'},
# ...

# %%
config_info["data_ingestion_config"]
# Out:
# {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#  'raw_data_dir': 'raw_data',
#  'tgz_download_dir': 'tgz_data',
#  'ingested_dir': 'ingested_data',
#  'ingested_train_dir': 'train',
#  'ingested_test_dir': 'test'}

# %%
def read_yaml_file(file_path:str)->dict:   
    """ Reads a YAML file and returns the contents as a dictionary
    file_path:str"""
    try:
        with open(config_file_path,"rb") as yaml_file:
            return yaml.safe_load(yaml_file)
    except Exception as e:
        raise e

# %%
read_yaml_file(config_file_path)
# Out:
# {'training_pipeline_config': {'pipeline_name': 'housing',
#   'artifact_dir': 'artifact'},
#  'data_ingestion_config': {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#   'raw_data_dir': 'raw_data',
#   'tgz_download_dir': 'tgz_data',
#   'ingested_dir': 'ingested_data',
#   'ingested_train_dir': 'train',
#   'ingested_test_dir': 'test'},
#  'data_validation_config': {'schema_file_name': 'schema.yaml'},
#  'data_trasnformation_config': {'add_bedroom_per_room': True,
#   'transformed_dir': 'trasnformed_data',
#   'trasnformed_train_dir': 'train',
#   'transformed_test_dir': 'test',
#   'preprocessing_dir': 'preprocessed',
#   'preprocessed_object_file_name': 'preprocessed.pkl'},
#  'model_trainer_config': {'trained_model_dir': 'trained_model',
#   'model_file_name': 'model.pkl',
#   'base_acuracy': 0.6},
#  'model_evaluation_config': {'model_evaluation_file_name': 'model_evaluation.yaml'},
# ...

# %% [markdown]
# * Create a folder named "util" inside of the "housing" folder
# * create a file named "__init__.py"
# * create a file with the name "util.py" inside of the folder "util"
# * the "util.py" file will be used to write anyfunction that is not part of the pipeline itself.
# * which can be used in several places to execute the tasks
# * add the function "read_yaml_file" into the scrip
#
# ![image.png](attachment:5910066b-0f74-4e42-9fd9-8b5dbac3227c.png)

# %% [markdown]
# * Create a folder named "constant" inside of the "housing" folder
# * create an "__init__.py" file inside of the folder "constant"
# * the idea is to put here all the constant variables for later use
#
# ![image.png](attachment:11c7c47e-d56a-4574-8b60-ba6aebc9243a.png)

# %% [markdown]
# * start populating the "configuration.py" file located inside of the "config" folder inside of the "housing" folder
#
# ![image.png](attachment:016c2b39-ffd8-4b74-bce3-277e43d3db92.png)
#
# ![image.png](attachment:d8e775eb-bc30-434e-9cc1-0c2ea8adb557.png)

# %%
config_info
# Out:
# {'training_pipeline_config': {'pipeline_name': 'housing',
#   'artifact_dir': 'artifact'},
#  'data_ingestion_config': {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#   'raw_data_dir': 'raw_data',
#   'tgz_download_dir': 'tgz_data',
#   'ingested_dir': 'ingested_data',
#   'ingested_train_dir': 'train',
#   'ingested_test_dir': 'test'},
#  'data_validation_config': {'schema_file_name': 'schema.yaml'},
#  'data_trasnformation_config': {'add_bedroom_per_room': True,
#   'transformed_dir': 'trasnformed_data',
#   'trasnformed_train_dir': 'train',
#   'transformed_test_dir': 'test',
#   'preprocessing_dir': 'preprocessed',
#   'preprocessed_object_file_name': 'preprocessed.pkl'},
#  'model_trainer_config': {'trained_model_dir': 'trained_model',
#   'model_file_name': 'model.pkl',
#   'base_acuracy': 0.6},
#  'model_evaluation_config': {'model_evaluation_file_name': 'model_evaluation.yaml'},
# ...

# %%
# data ingestion related variables
config_info['data_ingestion_config']
# Out:
# {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#  'raw_data_dir': 'raw_data',
#  'tgz_download_dir': 'tgz_data',
#  'ingested_dir': 'ingested_data',
#  'ingested_train_dir': 'train',
#  'ingested_test_dir': 'test'}

# %% [markdown]
# * add ingestion related varaibles to the "__init__.py" file in the constant  folder
#
# ![image.png](attachment:f4dbdf7a-828f-45c7-96e2-fae77700704c.png)

# %% [markdown]
# * add to the configuration.py file
#
# ![image.png](attachment:bc3ba462-33ad-42fb-aece-559e68cb1c46.png)
#
# ![image.png](attachment:f5179ed6-275d-4136-abf2-f769280b6b45.png)

# %% [markdown]
# * homework, fill the other components
#
# ![image.png](attachment:3cf5cf3d-f185-40e1-9c01-46448e1c8dd0.png)

# %% [markdown]
# * since the data_ingestion configuration has been finished, we can populate the "data_ingestion.py" file located in the "component" folder

# %% [markdown]
# # general info
#
# ![image.png](attachment:d658fa0d-87e8-4ca1-a0d9-d85a977cf220.png)

# %% [markdown]
# * in the "Entity" folder create an "artifact_entity.py" file, this helps in creating all the outputs
#
# ![image.png](attachment:12dcdec2-6dd3-4915-aa0c-5eafb2c5a6e8.png)
#
# * in the housing/component/data_ingestion.py file add the other required modules related to artifact_entity:
#
#
# * install the library six in the terminal
#
# ![image.png](attachment:7aab3154-bf5d-4284-9784-1477e8765ed2.png)

# %% [markdown]
# # Fill the DataIngestion

# %% [markdown]
# * import libraries
#
# ![image.png](attachment:23957a2f-0ea2-42cb-a484-056b5b23dd83.png)

# %% [markdown]
# * create the class
# * deff __init__ pass the corresponding info to the class
#
# ![image.png](attachment:adbfff39-7bb3-45c5-86b4-634752471684.png)

# %% [markdown]
# * download housing data
#     * gets the tgz url address
#     * gets the tgz folder location
#     * creates tgz_data directory
#     * extracts the name of the file
#     * creates the tgz path
#     * download the tgz and returns the tgz_file_path
#
# ![image.png](attachment:52b65caf-9fc2-4b95-9c31-936757af12ed.png)

# %% [markdown]
# * extract_tgz_file (requires the tgz_file_path)
#     * gets the directory  raw_data
#     * creates the raw_data folder
#     * extracts the tgz file into the raw directory
#
# ![image.png](attachment:3de8fe90-6e72-4ee8-bc35-4642b15207e4.png)

# %% [markdown]
# * splits the data
#     * gets the raw data directory
#     * gets the name of the file in it
#     * reads the file
#     * creates a new feature
#     * splits the data into train/test
#     * creates file paths for train/test data and creates the directories
#     * export the train/test datasets into the corresponding folders
#     * calls the datainestionartifact module as described in the "housing|entity|artifact_entity.py" file
#     * returns data_intestion_artifact
#
#
# ![image.png](attachment:669fb2a1-6c62-47fe-b386-0785dc32a3c2.png)
# ![image.png](attachment:60caf51c-2a4a-4519-9852-f09292b78321.png)

# %% [markdown]
# * initiate_data_ingestion
#     * gets the tgz file path
#     * extracts the data
#     * splits the data
#
# ![image.png](attachment:d24b3fd1-ee87-4210-ac9c-af8c0e08fd7b.png)

# %% [markdown]
# # PIPELINE
# * Testing the data ingestion

# %% [markdown]
# ![image.png](attachment:f422cd62-05a2-4f5c-aa72-f45a2f6eb902.png)
#
# ![image.png](attachment:6f15bb18-e830-4255-bbd6-d696745f94b1.png)

# %% [markdown]
# # Create a "schem.yaml" file inside of the main project folder

# %%
from six.moves import urllib  # a package that collects several modules for working with URLs
import pandas as pd
import tarfile

# %%
_url = "https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz"
_url
# Out:
# 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz'

# %%
urllib.request.urlretrieve(_url,"D:\\lh_data\\ineuron\\project_ml\\tgz_haousing")  # downloads the tgz file
# Out:
# ('D:\\lh_data\\ineuron\\project_ml\\tgz_haousing',
#  <http.client.HTTPMessage at 0x19b1808ec88>)

# %%
with tarfile.open("D:\\lh_data\\ineuron\\project_ml\\tgz_haousing") as file:
    file.extractall(path="D:\\lh_data\\ineuron\\project_ml\\raw\\")

# %%
housing_data_frame=pd.read_csv("D:\\lh_data\\ineuron\\project_ml\\raw\\housing.csv")
housing_data_frame
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# Bin values into discrete intervals.
import numpy as np
housing_data_frame["income_cat"] = pd.cut(  housing_data_frame["median_income"],
                                            bins=[0.0,1.5,3.0,4.5,6.0,np.inf],
                                            labels=[1,2,3,4,5])

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)   #keeps the feature distribution

# %%
for train_index, test_index in split.split(housing_data_frame,housing_data_frame["income_cat"]):
    train_set = housing_data_frame.loc[train_index]
    test_set = housing_data_frame.loc[test_index]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.pie(housing_data_frame.income_cat.value_counts(), labels=housing_data_frame.income_cat.value_counts().index)
plt.show()

# %%
### notice the same feature distribution in the input and in the splitted datasets, due to the use of StratifiedShuffleSplit

# train
plt.pie(train_set.income_cat.value_counts(), labels=train_set.income_cat.value_counts().index)
plt.show()
# test
plt.pie(test_set.income_cat.value_counts(), labels=test_set.income_cat.value_counts().index)
plt.show()

# %%
housing_data_frame.dtypes
# Out:
# longitude              float64
# latitude               float64
# housing_median_age     float64
# total_rooms            float64
# total_bedrooms         float64
# population             float64
# households             float64
# median_income          float64
# median_house_value     float64
# ocean_proximity         object
# income_cat            category
# dtype: object

# %%
housing_data_frame.dtypes.index, housing_data_frame.dtypes.values
# Out:
# (Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#         'total_bedrooms', 'population', 'households', 'median_income',
#         'median_house_value', 'ocean_proximity', 'income_cat'],
#        dtype='object'),
#  array([dtype('float64'), dtype('float64'), dtype('float64'),
#         dtype('float64'), dtype('float64'), dtype('float64'),
#         dtype('float64'), dtype('float64'), dtype('float64'), dtype('O'),
#         CategoricalDtype(categories=[1, 2, 3, 4, 5], ordered=True)],
#        dtype=object))

# %%
data_type = list(map(lambda x:str(x).replace("dtype('","").replace(")",""), housing_data_frame.dtypes.values))
data_type
# Out:
# ['float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'float64',
#  'object',
#  'category']

# %%
columns = housing_data_frame.columns
columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'income_cat'],
#       dtype='object')

# %%
dict(zip(columns,data_type))   # way to create schemas automatically
# Out:
# {'longitude': 'float64',
#  'latitude': 'float64',
#  'housing_median_age': 'float64',
#  'total_rooms': 'float64',
#  'total_bedrooms': 'float64',
#  'population': 'float64',
#  'households': 'float64',
#  'median_income': 'float64',
#  'median_house_value': 'float64',
#  'ocean_proximity': 'object',
#  'income_cat': 'category'}

# %% [markdown]
# * creae aschema.yaml file, specifies how is your data, how many columns, columns name and type of data, any categorial features is presented with its possible values
#
# ![image.png](attachment:f4d0dcdd-8734-4abf-a4a4-1b814057726c.png)

# %% [markdown]
# * update the "constant|__init__.py" file
#
# ![image.png](attachment:a8ee5e55-d240-44d2-b935-78712dee3287.png)

# %% [markdown]
# # flow chart
#
# ![image.png](attachment:d16755c4-6ef1-47bb-b3eb-edc1a09584c6.png)

# %% [markdown]
# * add the configuration for the data_validation_config
#
# ![image.png](attachment:c73fd8b0-3f9c-45c2-83e6-fab34bd3aebb.png)

# %% [markdown]
# * then go to the constant folder, and add the corresponding constants
#
# ![image.png](attachment:7e85b2f0-5d55-4557-a8a4-10efb2e16507.png)

# %% [markdown]
# * then go to "configuration.py file" where we will work on the "get_dat_validation_config", but before that,
# * check the "entity|config_entity.py" file to see how the validation is configured and add the variables for a validation report

# %% [markdown]
# ![image.png](attachment:e7a639e3-43d4-440a-a2ea-a74ba7829b4c.png)

# %% [markdown]
# * update the changes in the "config|config.yaml" file
#
# ![image.png](attachment:5d3f7c90-7191-4fa5-95a1-ebc0be97b878.png)

# %% [markdown]
# * and also UPDATE in the constat folder
#
# ![image.png](attachment:a25f0a16-f118-48e1-89ef-ccb26a99586c.png)

# %% [markdown]
# * in the "housing|config|configuration.py" file  add the code for the "get_data_validation_config()" module
#
# ![image.png](attachment:d102688c-1151-4641-9fbd-e452c0665c6b.png)

# %% [markdown]
# * know we work in the |component|data_validation.py file
