# %% [markdown]
# # Start MODEL EVALUATION
#
# * config.yaml
#
# ![image.png](attachment:fb9a2c9d-e088-4c6b-86ef-aa8eb097da50.png)

# %% [markdown]
# * update constant file
#
# ![image.png](attachment:4b2570c3-e500-4fe1-b758-5bb10469b742.png)

# %% [markdown]
# * update config|configuration.py file
#
# ![image.png](attachment:d87b094c-f1d3-45c9-8a8d-708b08b7e741.png)

# %% [markdown]
# * update the entity|artefact_entity.py with the model evaluation info
#
# ![image.png](attachment:9c6390f9-17f1-4f04-9af7-13b70db6e762.png)

# %% [markdown]
# * MODEL EVALUATION
#
# ![image.png](attachment:c3cfba6d-438a-42bd-8840-ec2c6cc6a1a2.png)
#
# ![image.png](attachment:7ee12f84-af06-49ae-ba05-f0789302a699.png)
#
# ![image.png](attachment:988d965e-1472-4969-a615-3a75b02a719c.png)
#
# ![image.png](attachment:2abd6218-331d-4ac2-83df-ab433f933b6d.png)
#
# ![image.png](attachment:aab306ca-7a94-4d6a-8989-fa506a161a0a.png)
#
# ![image.png](attachment:3af855ce-23a9-4632-bd26-28b477123451.png)

# %% [markdown]
# # MODEL PUSHER
#
# * start with the config.yaml
#
# ![image.png](attachment:e55cf264-736c-4788-a16c-9955cad80f5c.png)

# %% [markdown]
# * update config|configuration.py file
#
# ![image.png](attachment:9ee43907-d56c-469d-ab5a-0d64a7d1c024.png)

# %% [markdown]
# * update entity|artifact_entity.py file
#
# ![image.png](attachment:83ba5965-13ee-4958-8e77-de2b14654d7d.png)

# %% [markdown]
# * update housin|component|model_pusher.py file
#
# ![image.png](attachment:a6ef73a2-df29-4c7e-af31-afd7db2548d8.png)
#
# ![image.png](attachment:9681aa68-00df-4709-9a0d-b75000f6f796.png)

# %% [markdown]
# # putting a model into the web cloud
#
# ![image.png](attachment:6ce96adf-2d9c-437c-a61c-5de9a2c9bc8f.png)

# %% [markdown]
# ![image.png](attachment:f465da61-a8f0-4fd8-93c5-4b2a60755bd1.png)
#
# * how to upload a file from any cloud
#
# ![image.png](attachment:79add42c-d968-4b64-9765-8f8213d130f1.png)
# https://github.com/avnyadav/19thMLDL_fitbit/tree/main/webapp/cloud_storage_layer

# %% [markdown]
# * SELECTING A PROJECT
#
# ![image.png](attachment:fa88d24c-3b2e-4bc6-aa57-5c04e15dd73f.png)
